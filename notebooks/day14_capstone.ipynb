# %% [markdown]
# # Day 14 — Capstone end-to-end project
#
# This is the headline portfolio piece. Reuse this scaffold with your own dataset.
#
# ## Deliverables
# - GitHub repo with a clear README
# - Reproducible training script
# - Saved model artifact
# - FastAPI inference endpoint (reuse `day13_deploy/`)
# - (optional) Streamlit demo UI
# - 1-page write-up: problem, data, approach, results, what you'd do next

# %% [markdown]
# ## 0. Project metadata
# _Fill these in:_
# - **Project name:**
# - **Problem statement (1 sentence):**
# - **Why it matters (1 sentence):**
# - **Target variable & metric:**
# - **Data source & licence:**

# %% [markdown]
# ## 1. Setup

# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt, seaborn as sns
from pathlib import Path
RANDOM_STATE = 0
DATA = Path('data')

# %% [markdown]
# ## 2. Load + sanity-check data

# %%
# df = pd.read_csv(DATA / 'train.csv')
# print(df.shape); print(df.dtypes); print(df.isna().mean().sort_values(ascending=False).head(10))

# %% [markdown]
# ## 3. EDA (target, distributions, missingness, leakage check)

# %%
# Add 8-10 plots with one-line takeaways each.

# %% [markdown]
# ## 4. Data split (be careful with time-based or grouped data!)

# %%
# from sklearn.model_selection import train_test_split, GroupShuffleSplit, TimeSeriesSplit
# X_tr, X_va, y_tr, y_va = train_test_split(...)

# %% [markdown]
# ## 5. Baseline model

# %%
# from sklearn.dummy import DummyClassifier  # or DummyRegressor
# baseline = DummyClassifier(strategy='most_frequent').fit(X_tr, y_tr)
# print(baseline_score)

# %% [markdown]
# ## 6. Feature engineering + Pipeline

# %%
# from sklearn.compose import ColumnTransformer
# from sklearn.pipeline import Pipeline
# pre = ColumnTransformer([...])
# pipe = Pipeline([('pre', pre), ('clf', model)])

# %% [markdown]
# ## 7. Modeling — try 3+ models with CV

# %%
# from sklearn.model_selection import cross_val_score
# for name, m in models.items():
#     ...

# %% [markdown]
# ## 8. Tune the best with Optuna

# %%
# import optuna
# def objective(trial): ...
# study = optuna.create_study(direction='maximize'); study.optimize(objective, n_trials=50)

# %% [markdown]
# ## 9. Interpret with SHAP

# %%
# import shap
# explainer = shap.TreeExplainer(best.named_steps['clf'])
# shap.summary_plot(explainer.shap_values(X_processed), X_processed)

# %% [markdown]
# ## 10. Save artifact + write README + deploy

# %%
# import joblib
# joblib.dump(best, 'model.joblib')
# # then copy into day13_deploy/, edit app.py to match the new schema, build & run

# %% [markdown]
# ## 11. Write-up
# _Use this template:_
#
# **Problem.** _What were you predicting and why?_
#
# **Data.** _Source, size, key features, known limitations._
#
# **Approach.** _Baseline -> features -> models -> tuning -> chosen final model._
#
# **Results.** _Metric on val/test vs baseline. One chart that tells the story._
#
# **Limitations & next steps.** _Be honest about what's missing._
